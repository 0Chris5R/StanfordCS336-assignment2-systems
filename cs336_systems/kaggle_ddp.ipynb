# %% [markdown]
# # CS336 Assignment 2 - Naive DDP on Kaggle

# %% [markdown]
# ## 1. Verify GPU Availability

# %%
# !nvidia-smi

# %% [markdown]
# ## 2. Clone Repositories

# %%
# !git clone https://github.com/0Chris5R/StanfordCS336-Own-Transformer.git assignment1-basics
# !git clone https://github.com/0Chris5R/StanfordCS336-assignment2-systems.git assignment2-systems

# %%
# !pip install -e assignment1-basics
# !pip install -e assignment2-systems

# %%
import cs336_basics
import cs336_systems
print("Imports successful!")

# %% [markdown]
# ## 3. Run DDP Naive

# %%
# %cd assignment2-systems

# %%
# !python -m cs336_systems.ddp_naive

# %% [markdown]
# ## 4. Nsight Systems Profiling
#
# Profile naive DDP vs parameter overlap DDP to compare compute/communication overlap.

# %%
# Check if nsys is installed, if not install from NVIDIA devtools repo
# !which nsys || (echo "Installing Nsight Systems..." && \
    apt-get update && \
    apt-get install -y wget && \
    wget -qO - https://developer.download.nvidia.com/devtools/repos/ubuntu2204/amd64/nvidia.pub | apt-key add - && \
    echo "deb https://developer.download.nvidia.com/devtools/repos/ubuntu2204/amd64/ /" >> /etc/apt/sources.list.d/nsight.list && \
    apt-get update && \
    apt-get install -y nsight-systems-cli)

# %%
# !nsys profile --trace=cuda,nvtx --output=ddp_profile --force-overwrite=true python -m cs336_systems.ddp_naive

# %%
# !ls -la *.nsys-rep
